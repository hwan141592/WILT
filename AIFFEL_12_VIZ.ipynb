# %%
# pip install matplotlib
# pip install seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# #### one cell

# %%
subject = ['Eng','Math','Kor','Sci','Comp']
scores = [90,40,50,70,100]

# draw axis
fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

# draw graph
ax1.bar(subject,scores)

# label, title, ... 
plt.xlabel("Subject")
plt.ylabel("Points")
plt.title("test result")

# show
plt.savefig('./barplot.png')   # save graph as image
plt.show()                     # print graph

# %% [markdown]
# #### step by step

# %% [markdown]
# data

# %%
subject = ['Eng','Math','Kor','Sci','Comp']
scores = [90,40,50,70,100]

# %% [markdown]
# axis

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
ax1 = fig.add_subplot(2,1,2)

# %%
fig = plt.figure()   # generate fig object

# %%
fig = plt.figure(figsize=(5,2))
ax1 = fig.add_subplot(1,1,1)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,4)

# %% [markdown]
# graph

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,2,1)
ax2 = fig.add_subplot(2,2,2)
ax3 = fig.add_subplot(2,2,4)

ax1.bar(subject,scores)
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# axis & plt.options

# %%
fig = plt.figure()
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

# ax1.bar(subject,scores)
# plt.xlabel("subject")
# plt.ylabel("points")
plt.title("test result")
# Out:
# Text(0.5, 1.0, 'test result')

# %%
fig = plt.figure()
ax2 = fig.add_subplot(1,2,2)
ax1 = fig.add_subplot(1,2,1)

# ax1.bar(subject,scores)
# plt.xlabel("subject")
# plt.ylabel("points")
plt.title("test result")
# Out:
# Text(0.5, 1.0, 'test result')

# %%
subject = ['Eng','Math','Kor','Sci','Comp']
scores = [90,40,50,70,100]

fig = plt.figure()
ax1 = fig.add_subplot(1,1,1)

ax1.bar(subject, scores)

plt.xlabel('Subject')
plt.ylabel('scores')
plt.title("test result")
# Out:
# Text(0.5, 1.0, 'test result')

# %% [markdown]
# #### Line Graph (Series)

# %%
csv_path = "./data/AMZN2.csv"
data = pd.read_csv(csv_path ,index_col=0, parse_dates=True)
data.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-95bd1ebb0862> in <module>
#       1 csv_path = "./data/AMZN2.csv"
# ----> 2 data = pd.read_csv(csv_path ,index_col=0, parse_dates=True)
#       3 data.head(3)
#
# NameError: name 'pd' is not defined

# %%
from datetime import datetime
import pandas as pd
import os

csv_path = "./data/AMZN2.csv"
data = pd.read_csv(csv_path ,index_col=0, parse_dates=True)
price = data['Close']  # Series

fig = plt.figure()
ax = fig.add_subplot(1,1,1)
price.plot(ax=ax, style='black')
plt.ylim([1600,2200])
plt.xlim(['2019-05-01','2020-03-01'])

important_data = [(datetime(2019, 6, 3), "Low Price"),(datetime(2020, 2, 19), "Peak Price")]

# annotate : add letters or arrows
for d, label in important_data:
    ax.annotate(label, xy=(d, price.asof(d)+10), 
                xytext=(d,price.asof(d)+100),
                arrowprops=dict(facecolor='red'))

plt.grid()
ax.set_title('StockPrice')

plt.show()

# %% [markdown]
# #### plot usage

# %%
import numpy as np
x = np.linspace(0, 10, 100)
plt.plot(x, np.sin(x),'o')

# %%
import numpy as np
x = np.linspace(0,10,100)
plt.plot(x, np.sin(x), 'o')
plt.plot(x, np.cos(x), '--', color='black')
plt.show()

# %%
x = np.linspace(0,10,100)

plt.subplot(2,1,1)
plt.plot(x, np.sin(x), 'orange', 'o')
# Out:
# [<matplotlib.lines.Line2D at 0x7f8b6b987a60>,
#  <matplotlib.lines.Line2D at 0x7f8b6b987d00>]

# %%
x = np.linspace(0,10,100)

plt.subplot(2,1,1)
plt.plot(x, np.sin(x), 'orange', 'o')

plt.subplot(2,1,2)
plt.plot(x, np.cos(x), 'orange')

plt.show()

# %% [markdown]
# #### linestyle, marker option

# %%
x = np.linspace(0, 10, 100) 

plt.plot(x, x + 0, linestyle='solid') 
plt.plot(x, x + 1, linestyle='dashed') 
plt.plot(x, x + 2, linestyle='dashdot') 
plt.plot(x, x + 3, linestyle='dotted')
plt.plot(x, x + 0, '-g') # solid green 
plt.plot(x, x + 1, '--c') # dashed cyan 
plt.plot(x, x + 2, '-.k') # dashdot black 
plt.plot(x, x + 3, ':r'); # dotted red
plt.plot(x, x + 4, linestyle='-') # solid 
plt.plot(x, x + 5, linestyle='--') # dashed 
plt.plot(x, x + 6, linestyle='-.') # dashdot 
plt.plot(x, x + 7, linestyle=':'); # dotted

# %% [markdown]
# #### pandas plot()

# %% [markdown]
# pandas.plot메서드 인자
#  - label: 그래프의 범례이름.
#  - ax: 그래프를 그릴 matplotlib의 서브플롯 객체.
#  - style: matplotlib에 전달할 'ko--'같은 스타일의 문자열
#  - alpha: 투명도 (0 ~1)
#  - kind: 그래프의 종류: line, bar, barh, kde
#  - logy: Y축에 대한 로그스케일
#  - use_index: 객체의 색인을 눈금 이름으로 사용할지의 여부
#  - rot: 눈금 이름을 로테이션(0 ~ 360)
#  - xticks, yticks: x축, y축으로 사용할 값
#  - xlim, ylim: x축, y축 한계
#  - grid: 축의 그리드 표시할 지 여부
#
# pandas의 data가 DataFrame일때 plot 메서드 인자
#  - subplots: 각 DataFrame의 칼럼을 독립된 서브플롯에 그린다.
#  - sharex: subplots=True면 같은 X축을 공유하고 눈금과 한계를 연결한다.
#  - sharey: subplots=True면 같은 Y축을 공유한다.
#  - figsize: 그래프의 크기, 튜플로 지정
#  - title: 그래프의 제목을 문자열로 지정
#  - sort_columns: 칼럼을 알파벳 순서로 그린다.

# %%
fig, axes = plt.subplots(2, 1)
data = pd.Series(np.random.rand(5), index=list('abcde'))
data.plot(kind='bar', ax=axes[0], color='blue', alpha=1)
data.plot(kind='barh', ax=axes[1], color='red', alpha=0.3)

# %%
df = pd.DataFrame(np.random.rand(6,4), columns=pd.Index(['A','B','C','D']))
df.plot(kind='line')

# %% [markdown]
# #### 정리
#  - fig = plt.figure(): figure 객체를 선언해 '도화지를 펼쳐' 줍니다.
#  - ax1 = fig.add_subplot(1,1,1) : 축을 그립니다.
#  - ax1.bar(x, y) 축안에 어떤 그래프를 그릴지 메소드를 선택한 다음, 인자로 데이터를 넣어줍니다.
#  - 그래프 타이틀 축의 레이블 등을 plt의 여러 메소드 grid, xlabel, ylabel 을 이용해서 추가해주고
#  - plt.savefig 메소드를 이용해 저장해 줍니다.

# %% [markdown]
# #### plot_options names

# %%
from IPython.display import Image
Image("../img/plot_options.png")

# %% [markdown]
# ## Viz Again Step by Step

# %% [markdown]
# ### (1) 데이터 준비

# %%
import pandas as pd
import seaborn as sns
tips = sns.load_dataset("tips")
print(tips.shape); tips.head(3)
# Out:
# (244, 7)
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
df = pd.DataFrame(tips)
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3

# %%
df.shape
# Out:
# (244, 7)

# %%
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
df['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
df['time'].value_counts()

# %%
df['sex'].value_counts()

# %%
df['sex'].value_counts()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0.0, 2 * np.pi, 0.1)
sin_y = np.sin(x)
cos_y = np.cos(x)

fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
sns.distplot(x)
ax1.plot(x, sin_y, 'b--')
ax1.plot(x, cos_y, 'r--')

ax2 = fig.add_subplot(2, 1, 2)
sns.distplot(x)
ax2.plot(x, cos_y, 'r--')

plt.show()

# %%
import seaborn as sns
