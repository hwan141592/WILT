# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mu, sigma = 0.5, 0.1
s = np.random.normal(mu, sigma, 1000)

# %%
len(s)
# Out:
# 1000

# %%
s[0:3]
# Out:
# array([0.41365326, 0.41948731, 0.44441793])

# %%
count, bins, ignored = plt.hist(s, 20)

# %%
count
# Out:
# array([  1.,   1.,   3.,   5.,  15.,  19.,  56.,  85.,  83., 106., 106.,
#        135., 103.,  95.,  79.,  54.,  28.,  14.,   7.,   5.])

# %%
bins
# Out:
# array([0.12144857, 0.15550004, 0.18955151, 0.22360299, 0.25765446,
#        0.29170593, 0.3257574 , 0.35980887, 0.39386034, 0.42791181,
#        0.46196328, 0.49601475, 0.53006622, 0.56411769, 0.59816916,
#        0.63222063, 0.6662721 , 0.70032357, 0.73437504, 0.76842651,
#        0.80247798])

# %%
ignored
# Out:
# <a list of 20 Patch objects>

# %%
count, bins, ignored = plt.hist(s, 20, density=True)  
plt.plot(bins
       , 1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2))
       , linewidth=3
       , color='y'
)
plt.show()

# %%
plt.plot(bins)
