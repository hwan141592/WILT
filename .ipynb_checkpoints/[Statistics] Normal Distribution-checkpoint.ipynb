# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mu, sigma = 0.5, 0.1
s = np.random.normal(mu, sigma, 1000)

# %%
type(s)
# Out:
# numpy.ndarray

# %%
len(s)
# Out:
# 1000

# %%
s[0:3]
# Out:
# array([0.6176747 , 0.59246283, 0.45040665])

# %%
count, bins, ignored = plt.hist(s, 20)

# %%
count
# Out:
# array([  2.,   4.,  10.,  21.,  31.,  49.,  61.,  94.,  93., 115., 119.,
#        100.,  92.,  71.,  58.,  37.,  24.,  11.,   5.,   3.])

# %%
bins
# Out:
# array([0.20016366, 0.22909613, 0.2580286 , 0.28696107, 0.31589355,
#        0.34482602, 0.37375849, 0.40269096, 0.43162343, 0.4605559 ,
#        0.48948838, 0.51842085, 0.54735332, 0.57628579, 0.60521826,
#        0.63415074, 0.66308321, 0.69201568, 0.72094815, 0.74988062,
#        0.7788131 ])

# %%
ignored
# Out:
# <a list of 20 Patch objects>

# %%
count, bins, ignored = plt.hist(s, 20, density=True)  
plt.plot(bins
       , 1/(sigma*np.sqrt(2*np.pi))*np.exp(-(bins-mu)**2/(2*sigma**2))
       , linewidth=3
       , color='y'
)
plt.show()

# %% [markdown]
# ## numpy.random.normal

# %%
mu, sigma = 0, 0.1
s = np.random.normal(mu, sigma, 1000)

# %%
abs(mu - np.mean(s))
# Out:
# 0.004568431244180356

# %%
abs(sigma - np.std(s, ddof=1))
# Out:
# 0.0020033541062895316

# %%
import matplotlib.pyplot as plt
count, bins, ignored = plt.hist(s, 30, density=True)
plt.plot(bins, 1/(sigma * np.sqrt(2 * np.pi)) *
               np.exp( - (bins - mu)**2 / (2 * sigma**2) ),
         linewidth=2, color='r')
plt.show()

# %%
np.random.normal(3, 2.5, size=(2, 4))
# Out:
# array([[ 4.76993491,  6.49543926, -2.79854284,  2.46035163],
#        [ 5.23190475,  3.05538923, -0.95472115,  3.26892248]])
