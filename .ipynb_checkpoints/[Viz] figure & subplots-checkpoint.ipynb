# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)
plt.show()

# %%
type(ax1)
# Out:
# matplotlib.axes._subplots.AxesSubplot

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %% [markdown]
#  - Axes : 하나의 subplot과 유사한 개념

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)

x = range(0,4)
y = [v*v for v in x]

ax1.plot(x,y)
ax2.bar(x,y)

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0.0, 2 * np.pi, 0.1)
sin_y = np.sin(x)
cos_y = np.cos(x)

fig = plt.figure()
ax1 = fig.add_subplot(2, 1, 1)
ax2 = fig.add_subplot(2, 1, 2)

ax1.plot(x, sin_y, 'b--')
ax2.plot(x, cos_y, 'r--')

plt.show()

# %%
from IPython.display import Image  # 주피터 노트북에 이미지 삽입
Image('./matplotlib_org.png')

# %% [markdown]
# ## subplot & subplots

# %% [markdown]
# #### subplot
#  - subplot : 일일이 다 설정해줘야 함

# %%
import matplotlib.pyplot as plt

plt.subplot(2,1,1)
plt.subplot(2,1,2)
plt.show()

# %%
import matplotlib.pyplot as plt

fig = plt.figure()
ax1 = fig.add_subplot(2,1,1)
ax2 = fig.add_subplot(2,1,2)
plt.show()

# %% [markdown]
# #### subplots
#  - 한 번에 설정해줄 수 있음

# %%
fig, axes = plt.subplots(nrows=2, ncols=1)
plt.show()

# %% [markdown]
# #### fig, ax 의미

# %%
fig, ax = plt.subplots()

# %% [markdown]
#  - subplots()에서는 2개의 값을 받을 수 있음.
#  - 2개 : figure & axes
#  - figure(fig) : 전체 subplot들을 담는 하나의 영역. 전체 사이즈.
#  - axes(ax) : 전체 중 낱낱개의 subplot들

# %%
print(fig)
# Out:
# Figure(432x288)

# %%
print(ax)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# 반면, subplot()의 경우는 하나의 값(axes)만 받을 수 있음.

# %%
ax = plt.subplot(2,1,1)

# %% [markdown]
# #### subplots
#  - matplotlib.pyplot.subplots(nrows=1, ncols=1, sharex=False, sharey=False, squeeze=True, subplot_kw=None, gridspec_kw=None, **fig_kw)
#    - nrows : 몇 행을 만들 것인지
#    - ncols : 몇 열을 만들 것인지
#    - sharex : Xtick의 값을 각각 공유할지 안 할지
#    - sharey : Ytick의 값을 각각 공유할지 안 할지

# %% [markdown]
# 여기까지

# %% [markdown]
# ## plt.axis()

# %%
plt.axis('on')   # 축과 이름을 보여줌 / default
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
plt.axis('off')   # 축과 이름을 제거
# Out:
# (0.0, 1.0, 0.0, 1.0)

# %%
plt.axis('equal')  # x축과 y축의 비율을 실제 똑같은 비율로 나오도록 함
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %%
plt.axis('scaled')   # x축과 y축의 비율을 실제 똑같은 비율로 나오게 함. & 여백을 축소
# Out:
# (-0.05500000000000001,
#  0.05500000000000001,
#  -0.05500000000000001,
#  0.05500000000000001)

# %% [markdown]
# ## 해석해보기

# %%
size_graph = 5
for idx_x in range(size_graph):
    fig, axes = plt.subplots(1, 2, figsize=(25, 3))
    axes[0].plot(np.random.rand(100))
    axes[0].set_ylim(0, 1.2)
    axes[0].set_ylabel('Probability', fontsize=20)
    # axes[0].grid()
    
    axes[1].plot(np.random.rand(100))
    axes[1].set_ylim(0, 2.4)
    axes[1].set_ylabel('Probability', fontsize=20)
    axes[1].grid()

# %% [markdown]
# #### step by step

# %%
fig, axes = plt.subplots(1, 2, figsize=(25, 3))
fig, axes = plt.subplots(1, 2, figsize=(25, 3))
fig, axes = plt.subplots(1, 2, figsize=(25, 3))
fig, axes = plt.subplots(1, 2, figsize=(25, 3))
fig, axes = plt.subplots(1, 2, figsize=(25, 3))

# %%
np.random.rand(100)[0:5]
# Out:
# array([0.48375579, 0.95920817, 0.37473345, 0.08792216, 0.08738202])

# %%
fig, axes = plt.subplots(1, 2, figsize=(25, 3))
axes[0].plot(np.random.rand(100))
axes[1].plot(np.random.rand(100))
