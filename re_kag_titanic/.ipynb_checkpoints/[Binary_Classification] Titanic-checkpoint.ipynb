# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn')   # set seaborn scheme
sns.set(font_scale=2.5)    # set seaborn font_scale at once

# ignore warmings
import warnings
warnings.filterwarnings('ignore')

# show plot inline
# %matplotlib inline

pd.set_option('max_colwidth', 100)    # max column width
# pd.options.display.max_rows = 999   # max row

# %% [markdown]
# # Overall Process
#  - [01] Dataset
#  - [02] Exploratory Data Analysis
#  - [03] Feature Engineering
#  - [04] Modeling
#  - [05] Training & Prediction
#  - [06] Evaluation

# %% [markdown]
# # [01] Dataset

# %%
df_train = pd.read_csv('./data/train.csv')
df_test = pd.read_csv('./data/test.csv')

# %%
df_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df_test.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch        Fare
# count   418.000000  418.000000  332.000000  418.000000  418.000000  417.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344   35.627188
# std     120.810458    0.841838   14.181209    0.896760    0.981429   55.907576
# min     892.000000    1.000000    0.170000    0.000000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000    7.895800
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000   14.454200
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000   31.500000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000  512.329200

# %% [markdown]
# ## 'How to Check' Null value

# %% [markdown]
# #### (1) by code

# %%
for col in df_train.columns :
    msg = 'column: {:>10}\t Pearcent of NaN value: {:.2f}%'.format(col, 100*(df_train[col].isnull().sum() / df_train[col].shape[0]))
    print(msg)
# Out:
# column: PassengerId	 Pearcent of NaN value: 0.00%
# column:   Survived	 Pearcent of NaN value: 0.00%
# column:     Pclass	 Pearcent of NaN value: 0.00%
# column:       Name	 Pearcent of NaN value: 0.00%
# column:        Sex	 Pearcent of NaN value: 0.00%
# column:        Age	 Pearcent of NaN value: 19.87%
# column:      SibSp	 Pearcent of NaN value: 0.00%
# column:      Parch	 Pearcent of NaN value: 0.00%
# column:     Ticket	 Pearcent of NaN value: 0.00%
# column:       Fare	 Pearcent of NaN value: 0.00%
# column:      Cabin	 Pearcent of NaN value: 77.10%
# column:   Embarked	 Pearcent of NaN value: 0.22%

# %%
for col in df_test.columns : 
    msg = 'column: {:>10}\t Percent of NaN value: {:.2f}%'.format(col, 100*(df_test[col].isnull().sum() / df_test[col].shape[0]))
    print(msg)
# Out:
# column: PassengerId	 Percent of NaN value: 0.00%
# column:     Pclass	 Percent of NaN value: 0.00%
# column:       Name	 Percent of NaN value: 0.00%
# column:        Sex	 Percent of NaN value: 0.00%
# column:        Age	 Percent of NaN value: 20.57%
# column:      SibSp	 Percent of NaN value: 0.00%
# column:      Parch	 Percent of NaN value: 0.00%
# column:     Ticket	 Percent of NaN value: 0.00%
# column:       Fare	 Percent of NaN value: 0.24%
# column:      Cabin	 Percent of NaN value: 78.23%
# column:   Embarked	 Percent of NaN value: 0.00%

# %% [markdown]
# #### (2) using 'missingno' package

# %%
import missingno as msno

# %%
msno.matrix(df=df_train.iloc[:, :], figsize=(8,8), color=(0.8, 0.5, 0.2))

# %%
msno.matrix(df_train.sample(250))

# %%
msno.bar(df_train.sample(500))

# %%
msno.heatmap(df_train)

# %%
msno.dendrogram(df_train)

# %% [markdown]
# #### (3) using seaborn package

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.heatmap(df_train.isnull(), cbar=False)

# %% [markdown]
# ## 'Check' Null value

# %%
import missingno as msno

# %%
msno.bar(df=df_train.iloc[:, :], figsize=(8,8), color=(0.8, 0.5, 0.2))

# %%
msno.bar(df=df_test.iloc[:, :], figsize=(8,8), color=(0.8, 0.5, 0.2))

# %% [markdown]
# ## Check Target Label
#  - check the distribution of target label
#  - ex) In Binary classification, evaluation metric can be differ according to the distribution of 0 and 1.

# %%
f, ax = plt.subplots(1,2,figsize=(18,8))

df_train['Survived'].value_counts().plot.pie(explode=[0,0.1]
                                             , autopct='%1.1f%%'
                                             , ax=ax[0], shadow=True)
ax[0].set_title('Pie Chart - Survived')
ax[0].set_ylabel('')
sns.countplot('Survived', data=df_train, ax=ax[1])
ax[1].set_title('Counting - Survived')

plt.show()

# %% [markdown]
# # [02] EDA
#  - Exploratory Data Analysis

# %%
df_train.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# ### [feature.01] Pclass

# %%
df_train[['Pclass', 'Survived']].head()
# Out:
#    Pclass  Survived
# 0       3         0
# 1       1         1
# 2       3         1
# 3       1         1
# 4       3         0

# %%
df_train.shape
# Out:
# (891, 12)

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'], as_index=True).count()
# Out:
#         Survived
# Pclass
# 1            216
# 2            184
# 3            491

# %%
df_train[['Pclass','Survived']].groupby(['Pclass'], as_index=True).sum()
# Out:
#         Survived
# Pclass
# 1            136
# 2             87
# 3            119

# %% [markdown]
# -> Among passengers in Pclass 1, 136 people survived
# -> Among passengers in Pclass 2, 87 people survived
# -> Among passengers in Pclass 3, 119 people survived

# %%
df_train[['Pclass','Survived']].groupby(['Pclass'], as_index=True).mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %% [markdown]
# -> survival rate per Pclass

# %%
pd.crosstab(df_train['Pclass'], df_train['Survived'], margins=True)
# Out:
# Survived    0    1  All
# Pclass
# 1          80  136  216
# 2          97   87  184
# 3         372  119  491
# All       549  342  891

# %%
pd.crosstab(df_train['Pclass'],
            df_train['Survived'],
            margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row0_col1 {
#             background-color:  #cee666;
#             color:  #000000;
#         }    #T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row0_col2 {
#             background-color:  #f4fa66;
#             color:  #000000;
#         }    #T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row1_col0 {
#             background-color:  #f6fa66;
#             color:  #000000;
#         }    #T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row1_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row2_col0 {
#             background-color:  #60b066;
#             color:  #000000;
#         }    #T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row2_col1 {
#             background-color:  #dfef66;
#             color:  #000000;
#         }    #T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row2_col2 {
#             background-color:  #90c866;
#             color:  #000000;
#         }    #T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row3_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row3_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row3_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_e1740b24_294d_11ea_a8c2_cc3d82e85c78" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Pclass</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e1740b24_294d_11ea_a8c2_cc3d82e85c78level0_row0" class="row_heading level0 row0" >1</th>
#                         <td id="T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row0_col0" class="data row0 col0" >80</td>
#                         <td id="T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row0_col1" class="data row0 col1" >136</td>
#                         <td id="T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row0_col2" class="data row0 col2" >216</td>
#             </tr>
#             <tr>
#                         <th id="T_e1740b24_294d_11ea_a8c2_cc3d82e85c78level0_row1" class="row_heading level0 row1" >2</th>
#                         <td id="T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row1_col0" class="data row1 col0" >97</td>
#                         <td id="T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row1_col1" class="data row1 col1" >87</td>
#                         <td id="T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row1_col2" class="data row1 col2" >184</td>
#             </tr>
#             <tr>
#                         <th id="T_e1740b24_294d_11ea_a8c2_cc3d82e85c78level0_row2" class="row_heading level0 row2" >3</th>
#                         <td id="T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row2_col0" class="data row2 col0" >372</td>
#                         <td id="T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row2_col1" class="data row2 col1" >119</td>
#                         <td id="T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row2_col2" class="data row2 col2" >491</td>
#             </tr>
#             <tr>
#                         <th id="T_e1740b24_294d_11ea_a8c2_cc3d82e85c78level0_row3" class="row_heading level0 row3" >All</th>
#                         <td id="T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row3_col0" class="data row3 col0" >549</td>
#                         <td id="T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row3_col1" class="data row3 col1" >342</td>
#                         <td id="T_e1740b24_294d_11ea_a8c2_cc3d82e85c78row3_col2" class="data row3 col2" >891</td>
#             </tr>
#     </tbody></table>

# %%
df_train[['Pclass', 'Survived']].groupby(['Pclass'],as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar()

# %%
y_position = 1.02
f, ax = plt.subplots(1,2,figsize=(18,8))

df_train['Pclass'].value_counts().plot.bar(color=['#CD7F32','#FFDF00','#D3D3D3'], ax=ax[0])
ax[0].set_title('Number of Passengers By Pclass', y=y_position)
ax[0].set_ylabel('Count')

sns.countplot('Pclass', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Pclass:Survived vs. Dead', y=y_position)

plt.show()

# %% [markdown]
# -> the better the Pclass, the more people are alive
# -> Pclass is good feature to predict 'Survival'

# %% [markdown]
# ### [feature.02] Sex

# %%
f, ax = plt.subplots(1, 2, figsize=(18,8))

df_train[['Sex', 'Survived']].groupby(['Sex'], as_index=True).mean().plot.bar(ax=ax[0])
ax[0].set_title('Survived vs. Sex')

sns.countplot('Sex', hue='Survived', data=df_train, ax=ax[1])
ax[1].set_title('Sex : survived vs. Dead')

plt.show()

# %% [markdown]
# -> women seems to be more likely to survive rather than men

# %%
df_train[['Sex','Survived']].groupby(['Sex'], as_index=False).mean().sort_values(by='Survived', ascending=False)
# Out:
#       Sex  Survived
# 0  female  0.742038
# 1    male  0.188908

# %%
pd.crosstab(df_train['Sex'], df_train['Survived'], margins=True)
# Out:
# Survived    0    1  All
# Sex
# female     81  233  314
# male      468  109  577
# All       549  342  891

# %%
pd.crosstab(df_train['Sex']
            , df_train['Survived']
            , margins=True).style.background_gradient(cmap='summer_r')
# Out:
# <style  type="text/css" >
#     #T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78row0_col0 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78row0_col1 {
#             background-color:  #77bb66;
#             color:  #000000;
#         }    #T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78row0_col2 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78row1_col0 {
#             background-color:  #2c9666;
#             color:  #000000;
#         }    #T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78row1_col1 {
#             background-color:  #ffff66;
#             color:  #000000;
#         }    #T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78row1_col2 {
#             background-color:  #8bc566;
#             color:  #000000;
#         }    #T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78row2_col0 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78row2_col1 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }    #T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78row2_col2 {
#             background-color:  #008066;
#             color:  #f1f1f1;
#         }</style><table id="T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78" ><thead>    <tr>        <th class="index_name level0" >Survived</th>        <th class="col_heading level0 col0" >0</th>        <th class="col_heading level0 col1" >1</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level0" >Sex</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78level0_row0" class="row_heading level0 row0" >female</th>
#                         <td id="T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78row0_col0" class="data row0 col0" >81</td>
#                         <td id="T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78row0_col1" class="data row0 col1" >233</td>
#                         <td id="T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78row0_col2" class="data row0 col2" >314</td>
#             </tr>
#             <tr>
#                         <th id="T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78level0_row1" class="row_heading level0 row1" >male</th>
#                         <td id="T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78row1_col0" class="data row1 col0" >468</td>
#                         <td id="T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78row1_col1" class="data row1 col1" >109</td>
#                         <td id="T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78row1_col2" class="data row1 col2" >577</td>
#             </tr>
#             <tr>
#                         <th id="T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78level0_row2" class="row_heading level0 row2" >All</th>
#                         <td id="T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78row2_col0" class="data row2 col0" >549</td>
#                         <td id="T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78row2_col1" class="data row2 col1" >342</td>
#                         <td id="T_e50f6fa2_294d_11ea_9ce9_cc3d82e85c78row2_col2" class="data row2 col2" >891</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# -> sex is good feature to predict 'Survival'

# %% [markdown]
# ### [feature.(+a)] Both Pclass & Sex

# %%
sns.factorplot('Pclass', 'Survived', hue='Sex', data=df_train, size=6, aspect=1.5)

# %% [markdown]
# ### [feature.03] Age

# %%
print('the oldest : {:.1f} Years'.format(df_train['Age'].max()))
print('the youngest : {:.1f} Years'.format(df_train['Age'].min()))
print('mean age of all passengers : {:.1f} Years'.format(df_train['Age'].mean()))
# Out:
# the oldest : 80.0 Years
# the youngest : 0.4 Years
# mean age of all passengers : 29.7 Years

# %%
fig, ax = plt.subplots(1, 1, figsize=(9,5))

sns.kdeplot(df_train[df_train['Survived']==1]['Age'], ax=ax)
sns.kdeplot(df_train[df_train['Survived']==0]['Age'], ax=ax)

plt.legend(['Survived==1', 'Survived==0'])
plt.show()

# %% [markdown]
# -> when young, more likely to survive

# %%
plt.figure(figsize=(8,6))

df_train['Age'][df_train['Pclass']==1].plot(kind='kde')
df_train['Age'][df_train['Pclass']==2].plot(kind='kde')
df_train['Age'][df_train['Pclass']==3].plot(kind='kde')

plt.xlabel('Age')
plt.title('Age Distribution within classes')
plt.legend(['1st Class', '2nd Class', '3rd Class'])
plt.show()

# %% [markdown]
# -> the elder, the more number of 1st Class

# %% [markdown]
# ### [feature.(+b)] Pclass & Sex & Age

# %%
f,ax=plt.subplots(1,2,figsize=(18,8))

sns.violinplot("Pclass","Age", hue="Survived", data=df_train, scale='count', split=True,ax=ax[0])
ax[0].set_title('Pclass and Age vs Survived')
ax[0].set_yticks(range(0,110,10))

sns.violinplot("Sex","Age", hue="Survived", data=df_train, scale='count', split=True,ax=ax[1])
ax[1].set_title('Sex and Age vs Survived')
ax[1].set_yticks(range(0,110,10))

plt.show()

# %% [markdown]
# -> (left graph) : Within all Pclasses, the younger the more survived
# -> (right graph) : Obviousely, women survived more than men

# %% [markdown]
# ### [feature.04] Embarked
#  - Embarked : the harbor that passenger boarded on

# %%
f, ax = plt.subplots(1, 1, figsize=(7,7))
df_train[['Embarked', 'Survived']].groupby(['Embarked'], as_index=True).mean().sort_values(by='Survived', ascending=False).plot.bar(ax=ax)

# %%
f, ax = plt.subplots(2, 2, figsize=(20,15))

sns.countplot('Embarked', data=df_train, ax=ax[0, 0]) 
ax[0,0].set_title('(1) No. of passengers Boarded')

sns.countplot('Embarked', hue='Sex', data=df_train, ax=ax[0,1])
ax[0,1].set_title('(2) Male-Female Split for Embarked')

sns.countplot('Embarked', hue='Survived', data=df_train, ax=ax[1,0]) 
ax[1,0].set_title('(3) Embarked vs Survived')

sns.countplot('Embarked', hue='Pclass', data=df_train, ax=ax[1,1])
ax[1,1].set_title('(4) Embarked vs Pclass')

plt.subplots_adjust(wspace=0.2, hspace=0.5)
plt.show()

# %% [markdown]
# -> (1) Overall, most people went aboard at S
# -> (2) At S, more women went aboard, while other 2 are similar regardless of sex
# -> (3) Survival rate is very small at S
# -> (4) When split into Pclass, we can see...
# .....<1> At S, many people with Pclass 3 went aboard, so the survival rate is low.
# .....<2> At C, many people with Pclass 1 went aboard, so the survival rate is high.
